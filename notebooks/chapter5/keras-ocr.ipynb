# %% [markdown]
# https://www.youtube.com/watch?v=WtEhQvVUdH4

# %%
# !pip install -q keras-ocr
# Out:
#      |████████████████████████████████| 41 kB 335 kB/s
#      |████████████████████████████████| 123 kB 5.6 MB/s
#      |████████████████████████████████| 873 kB 16.9 MB/s
#      |████████████████████████████████| 9.5 MB 16.6 MB/s
#      |████████████████████████████████| 50 kB 6.8 MB/s

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...

# %%
images = [
          keras_ocr.tools.read(img) for img in ['2.jpg',
                                                '4.jpg'
                                                ]
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize=(10,20))
plt.imshow(images[0])

# %%
prediction_groups = pipeline.recognize(images)

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
  keras_ocr.tools.drawAnnotations(image=image,
                                  predictions=predictions,
                                  ax=ax
                                  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4cae6325cf50> in <module>()
#       3   keras_ocr.tools.drawAnnotations(image=image,
#       4                                   predictions=predictions,
# ----> 5                                   ax=ax
#       6                                   )
#
# /usr/local/lib/python3.7/dist-packages/keras_ocr/tools.py in drawAnnotations(image, predictions, ax)
#     182                 color="r",
#     183                 fontsize=14,
# --> 184                 horizontalalignment="right" if side == "left" else "left",
#     185             )
#     186     return ax
#
# TypeError: annotate() missing 1 required positional argument: 's'

# %%
prediction_groups
# Out:
# [[('l', array([[183.51562 ,   0.      ],
#           [237.9375  ,   0.      ],
#           [237.9375  ,   6.328125],
#           [183.51562 ,   6.328125]], dtype=float32)),
#   ('bian', array([[699.8906 ,   0.     ],
#           [883.40625,   0.     ],
#           [883.40625,  60.75   ],
#           [699.8906 ,  60.75   ]], dtype=float32)),
#   ('lamouine', array([[ 964.40625 ,    0.      ],
#           [1027.6875  ,    0.      ],
#           [1027.6875  ,    8.859375],
#           [ 964.40625 ,    8.859375]], dtype=float32)),
#   ('per', array([[1028.9531,    0.    ],
#           [1056.7969,    0.    ],
#           [1056.7969,   10.125 ],
#           [1028.9531,   10.125 ]], dtype=float32)),
#   ('sening', array([[1058.0625,    0.    ],
#           [1115.0156,    0.    ],
#           [1115.0156,   10.125 ],
#           [1058.0625,   10.125 ]], dtype=float32)),
#   ('oo', array([[260.93695 ,   3.88416 ],
#           [290.16855 ,   5.603662],
#           [289.65356 ,  14.358295],
# ...

# %%
prediction_groups[0][0][0]
# Out:
# 'pace'

# %%
len(prediction_groups[1])
# Out:
# 7

# %%
len(prediction_groups[0][0])
# Out:
# 2

# %%
for i in range(len(prediction_groups)):
  print("image:",  i)
  for j in range(len(prediction_groups[i])):
    #print(j)
    print(prediction_groups[i][j][0])
# Out:
# image: 0
# l
# bian
# lamouine
# per
# sening
# oo
# serving
# s
# cconas
# dire
# calories
# 110
# calories
# from
# fat
# 10
# adout
# coninen
# crad
# songe
# cavine
# f
# daily
# valuer
# calories
# calories
# 100
# from
# fat
# 5
# fat
# total
# l
# 59
# 200
# daily
# vo
# value
# saturated
# fat
# og
# 00
# o
# high
# in
# fiber
# total
# fat
# 5g
# t
# 2l0
# fat
# trans
# og
# saturated
# fat
# og
# cholesterol
# omg
# nutrition
# facts
# o
# 00
# sodium
# 5mg
# serving
# size
# trans
# fat
# og
# cup
# o00
# 61g
# servings
# per
# container
# about
# 9
# total
# carbohydrate
# 1g
# 610
# polyunsaturated
# fat
# o
# 5g
# dietary
# fiber
# ag
# 1610
# monounsaturated
# fat
# with
# h
# og
# cup
# amount
# per
# serving
# cereal
# sugars
# stim
# milk
# 7g
# cholesterol
# omg
# o
# calories
# 190
# 230
# protein
# 39
# calories
# fat
# sodium
# 1oomg
# from
# 10
# 10
# vitamin
# c
# o0
# vitamin
# a
# 00
# potassium
# 45mg
# 10
# olo
# daily
# value
# total
# fat
# 1g
# 200
# ...
